# %% [markdown]
# # Подключение библиотек

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Строим графики

# %% [markdown]
# ## random array

# %%
quick_sort_comparisons= pd.Series({1000 : 6329 , 2000 : 13640,3000 : 21247 ,4000 : 29067,5000 : 37102 ,6000 : 45273 ,7000 : 53500 ,8000 : 61876,9000 : 70336 ,10000: 78894,25000: 212234 ,50000: 447863,100000: 941952})
plt.plot(quick_sort_comparisons)
plt.title("число сравнений в быстрой сортировке")
plt.show()

# %%
quick_sort_copy = pd.Series({1000 : 4070 , 2000 : 8631,3000 : 13348 ,4000 : 18164,5000 : 23081 ,6000 : 28078 ,7000 : 33102 ,8000 : 38197,9000 : 43331 ,10000: 48526,25000: 128796 ,50000: 269289,100000: 561705})
plt.plot(quick_sort_copy)
plt.title("число копирования в быстрой сортировке")
plt.show()

# %%
selection_sort_comparisons = pd.Series({1000 : 499500 , 2000 : 1999000,3000 : 4498500 ,4000 : 7998000,5000 : 12497500 ,6000 : 17997000 ,7000 : 24496500 ,8000 : 31996000,9000 : 40495500 ,10000: 49995000,25000: 312487500 ,50000: 1249975000,100000: 4999950000})
plt.plot(selection_sort_comparisons)
plt.title("число сравнений в сортировке выбором")
plt.show()

# %%
selection_sort_copy = pd.Series({1000 : 1000 , 2000 : 2000,3000 : 3000 ,4000 : 4000,5000 : 5000 ,6000 : 6000 ,7000 : 7000 ,8000 : 8000,9000 : 9000 ,10000: 10000,25000: 25000 ,50000: 50000,100000: 100000})
plt.plot(selection_sort_copy)
plt.title("число копирования в сортировке выбором")
plt.show()

# %% [markdown]
# ## Sorted array

# %%
quick_sort_arr_comparisons= pd.Series({1000 : 1488 , 2000 : 2976,3000 : 4094 ,4000 : 5952,5000 : 7952 ,6000 : 8190 ,7000 : 9904 ,8000 : 11904,9000 : 13904 ,10000: 15904,25000: 33616 ,50000: 67232,100000: 134464})
plt.plot(quick_sort_arr_comparisons)
plt.title("число проверок в быстрой сортировке при отсортированном массиве")
plt.show()

# %%
quick_sort_arr_copy= pd.Series({1000 : 1488 , 2000 : 2976,3000 : 4094 ,4000 : 5952,5000 : 7952 ,6000 : 8190 ,7000 : 9904 ,8000 : 11904,9000 : 13904 ,10000: 15904,25000: 33616 ,50000: 67232,100000: 134464})
plt.plot(quick_sort_arr_copy)
plt.title("число копирований в быстрой сортировке при отсортированном массиве")
plt.show()

# %%
selection_sort_arr_comparisons= pd.Series({1000 : 499500 , 2000 : 1999000,3000 : 4498500 ,4000 : 7998000,5000 : 12497500 ,6000 : 17997000 ,7000 : 24496500 ,8000 : 31996000,9000 : 40495500 ,10000: 49995000,25000: 312487500 ,50000: 1249975000,100000: 4999950000})
plt.plot(selection_sort_arr_comparisons)
plt.title("число проверок в сортировке выбором при отсортированном массиве")
plt.show()

# %%
selection_sort_arr_copy= pd.Series({1000 : 1000 , 2000 : 2000,3000 : 3000 ,4000 : 4000,5000 : 5000 ,6000 : 6000 ,7000 : 7000 ,8000 : 8000,9000 : 9000 ,10000: 10000,25000: 25000 ,50000: 50000,100000: 100000})
plt.plot(selection_sort_arr_copy)
plt.title("число копирований в сортировке выбором при отсортированном массиве")
plt.show()

# %% [markdown]
# ## Reverse sorted array

# %%
quick_sort_reverse_arr_copy= pd.Series({1000 : 2488 , 2000 : 4976,3000 : 7092 ,4000 : 9952,5000 : 12952 ,6000 : 14188 ,7000 : 16904 ,8000 : 19904,9000 : 22904 ,10000: 25904,25000: 58616 ,50000: 117232,100000: 234464})
plt.plot(quick_sort_reverse_arr_copy)
plt.title("число проверок в быстрой сортировке при отсортированном массиве в обратном порядке")
plt.show()

# %%
quick_sort_arr_copy= pd.Series({1000 : 1989 , 2000 : 3977,3000 : 5593 ,4000 : 7953,5000 : 10453 ,6000 : 11189 ,7000 : 13405 ,8000 : 15905,9000 : 18405 ,10000: 20905,25000: 46117 ,50000: 92233,100000: 184465})
plt.plot(quick_sort_arr_copy)
plt.title("число копирований в быстрой сортировке при отсортированном массиве в обратном порядке")
plt.show()

# %%
selection_not_sort_arr_comparisons= pd.Series({1000 : 499500 , 2000 : 1999000,3000 : 4498500 ,4000 : 7998000,5000 : 12497500 ,6000 : 17997000 ,7000 : 24496500 ,8000 : 31996000,9000 : 40495500 ,10000: 49995000,25000: 312487500 ,50000: 1249975000,100000: 4999950000})
plt.plot(selection_not_sort_arr_comparisons)
plt.title("число проверок в сортировке выбором при отсортированном массиве в обратном порядке")
plt.show()

# %%
selection_not_sort_arr_copy= pd.Series({1000 : 1000 , 2000 : 2000,3000 : 3000 ,4000 : 4000,5000 : 5000 ,6000 : 6000 ,7000 : 7000 ,8000 : 8000,9000 : 9000 ,10000: 10000,25000: 25000 ,50000: 50000,100000: 100000})
plt.plot(selection_not_sort_arr_copy)
plt.title("число копирований в сортировке выбором при отсортированном массиве в обратном порядке")
plt.show()
